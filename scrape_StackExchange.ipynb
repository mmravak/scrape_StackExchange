# %% [markdown]
# ## <center> CSE STACK EXCHANGE - Prikupljanje podataka scrapeanjem </center>

# %% [markdown]
# #### Scrapeanje pomoću _scrapyja_

# %%
# !pip install scrapy
# Out:
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 Twisted-21.7.0 constantly-15.1.0 cryptography-36.0.1 cssselect-1.1.0 h2-3.2.0 hpack-3.0.0 hyperframe-5.2.0 hyperlink-21.0.0 incremental-21.3.0 itemadapter-0.4.0 itemloaders-1.0.4 jmespath-0.10.0 parsel-1.6.0 priority-1.3.0 protego-0.1.16 pyOpenSSL-21.0.0 queuelib-1.6.2 scrapy-2.5.1 service-identity-21.1.0 w3lib-1.22.0 zope.interface-5.4.0

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# ##### Kreiranje spidera

# %%
class SExchangeSpider(scrapy.Spider):
    
    name = "SExchangeSpider"
    
    start_urls = ['https://cseducators.stackexchange.com/questions/0']

    def parse(self, response):

        print("Status odgovora: ", response)
        print("Sadržaj odgovor: ", response.text)

        content = "".join(response.xpath('//div[@class="postcell post-layout--right"]/div[@class="s-prose js-post-body"]/p/text()').extract())
        print("Sadržaj pitanja: ", content)

# %% [markdown]
# ##### Pokretanje spidera

# %%
process = CrawlerProcess()
process.crawl(SExchangeSpider)
process.start()
# Out:
# 2022-01-20 17:00:15 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2022-01-20 17:00:15 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.12 (default, Sep 10 2021, 00:21:48) - [GCC 7.5.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic
# 2022-01-20 17:00:15 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-01-20 17:00:15 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2022-01-20 17:00:15 [scrapy.extensions.telnet] INFO: Telnet Password: bf8c92fc2699f6f5
# 2022-01-20 17:00:15 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2022-01-20 17:00:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-01-20 17:00:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-01-20 17:00:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-01-20 17:00:15 [scrapy.core.engine] INFO: Spider opened
# 2022-01-20 17:00:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-01-20 17:00:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-01-20 17:00:16 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://cseducators.stackexchange.com/questions/0> (referer: None)
# 2022-01-20 17:00:16 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <404 https://cseducators.stackexchange.com/questions/0>: HTTP status code is not handled or not allowed
# 2022-01-20 17:00:16 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-01-20 17:00:16 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 240,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 15617,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 0.352395,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 1, 20, 17, 0, 16, 229813),
#  'httpcompression/response_bytes': 47900,
#  'httpcompression/response_count': 1,
#  'httperror/response_ignored_count': 1,
#  'httperror/response_ignored_status_count/404': 1,
#  'log_count/DEBUG': 1,
#  'log_count/INFO': 11,
#  'memusage/max': 151638016,
#  'memusage/startup': 151638016,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2022, 1, 20, 17, 0, 15, 877418)}
# 2022-01-20 17:00:16 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# > Značajke koje smo dobili scrapeanjem pomoću scrapyja

# %%
import pandas as pd
scrapy_features_scrapy = pd.DataFrame({"Pitanje ne postoji": [0, 404, 'nepoznato', 'nepoznato', 'stranica ne postoji'],
                   "Pitanje je izbrisano": [1, 404, 'nepoznato', 'nepoznato', 'preusmjeravanje urla - pitanje je postojalo'],
                   "Pitanje postoji": [2, 200, 'cijeli html stranice', 'dohvaćen sadržaj pitanja', 'postoje podaci o pitanju']},
                  ["id", "response.status_code", "response.text", "question_content", "conclusion"])

# %%
scrapy_features_scrapy.rename_axis("features", axis="columns")
# Out:
# features               Pitanje ne postoji  ...           Pitanje postoji
# id                                      0  ...                         2
# response.status_code                  404  ...                       200
# response.text                   nepoznato  ...      cijeli html stranice
# question_content                nepoznato  ...  dohvaćen sadržaj pitanja
# conclusion            stranica ne postoji  ...  postoje podaci o pitanju
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Drugi način: scrapeanje koristeći _requests_ i _BeautifulSoup_

# %% [markdown]
# #### Pokretanje zahtjeva

# %%
import requests

response = requests.get('https://cseducators.stackexchange.com/questions/2')

# %% [markdown]
# #### Scrapeanje pomoću _Beautiful Soupa_

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text)

print("Status odgovora: ", response.status_code)
#print("Sadržaj odgovora: ", response.text)

content = "".join([i.text for i in soup.find('div', class_="s-prose js-post-body").find_all('p')])
print("Sadržaj pitanja: ", content)
# Out:
# Status odgovora:  200
# Sadržaj pitanja:  Grading currently either takes me a huge amount of time, or gets done in an extremely cursory way.  It occurs to me that, if my students were able to submit code into some sort of autotester, they would find many of their errors before I review their code.  This would mean that I would only have to look for clarity issues, not logic bugs.I am interested in software that (a) isn't too hard to set up, (b) will allow my students to test whether their code is (at least) to spec, and (c) allows me to quickly cycle through the code from all of the students in a section to look for style issues.I have looked far and wide, and have not yet found a reasonable system that accomplishes these three goals.  Many universities seem to have robust systems, but they all appear to be home-grown, and unavailable to outsiders.  Is anyone aware of such a system?  I honestly don't even care if it costs money - I just need a solution that makes this task more reasonable.

# %% [markdown]
# > Značajke koje smo dobili scrapeanjem pomoću Beautiful soupa

# %%
scrapy_features_bs = pd.DataFrame({"Pitanje ne postoji": [0, 404, 'cijela html stranica', 'nepoznato', 'stranica ne postoji'],
                   "Pitanje je izbrisano": [1, 404, 'cijela html stranica', 'nepoznato (postoji podatak o naslovu pitanja)', 'preusmjeravanje urla - pitanje je postojalo'],
                   "Pitanje postoji": [2, 200, 'cijeli html stranice', 'dohvaćen sadržaj pitanja', 'postoje podaci o pitanju']},
                  ["id", "response.status_code", "response.text", "question_content", "conclusion"])

# %%
scrapy_features_bs.rename_axis("features", axis="columns")
# Out:
# features                Pitanje ne postoji  ...           Pitanje postoji
# id                                       0  ...                         2
# response.status_code                   404  ...                       200
# response.text         cijela html stranica  ...      cijeli html stranice
# question_content                 nepoznato  ...  dohvaćen sadržaj pitanja
# conclusion             stranica ne postoji  ...  postoje podaci o pitanju
#
# [5 rows x 3 columns]

# %% [markdown]
# > **Odluka**: koristiti će se Beautiful soup jer se mogu dobiti cijele html stranice u *response* objektu te iz njih dohvaćati podatke ovisno o tome da li pitanje postoji, izbrisano je ili ne postoji za razliku od scrapyja koji ne vraća html stranice ako je *status_code* 404. ❗

# %% [markdown]
# #### Dohvaćanje podataka pomoću Beautiful soupa

# %%
# biblioteke
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %%
clean = re.compile('<.*?>')

# %% [markdown]
# > Ukupan broj pitanja koje sadrži Stack Exchange - CSE stranica

# %%
response = requests.get("https://cseducators.stackexchange.com/questions/")
soup = BeautifulSoup(response.text)
number_of_questions = soup.find("div",class_="fs-body3 flex--item fl1 mr12 sm:mr0 sm:mb12").text.strip().split(" ")[0]
print("Ukupan broj pitanja: ", number_of_questions)
# Out:
# Ukupan broj pitanja:  1,038

# %% [markdown]
# > ID posljednjeg pitanja na stranici

# %%
last_question_id = soup.find("div","question-summary").get("id")[-4:]
print("Id posljednjeg pitanja:", last_question_id)
# Out:
# Id posljednjeg pitanja: 7248

# %% [markdown]
# > Klasifikacija podataka

# %%
question_classification = pd.DataFrame({"Nepostojeće pitanje": [0, 'https://cseducators.stackexchange.com/questions/0', 'https://cseducators.stackexchange.com/questions/0', '404', 'Stranica ne postoji.'],
                   "Izbrisano pitanje": [1, 'https://cseducators.stackexchange.com/questions/1', 'https://cseducators.stackexchange.com/questions/1/what-language-should-be-first-used-to-introduce-coding', '404', 'Informacija o brisanju pitanja.'],
                   "Postojeće pitanje": [2, 'https://cseducators.stackexchange.com/questions/2', 'https://cseducators.stackexchange.com/questions/2', '200', 'Podaci o pitanju.'],
                   "Odgovor": [10, 'https://cseducators.stackexchange.com/questions/10', 'https://cseducators.stackexchange.com/questions/3/is-it-possible-to-ensure-division-of-labor-on-a-group-assignment/10#10', '200', 'Podaci o odgovoru.'],
                   "Tag": [15, 'https://cseducators.stackexchange.com/questions/15', 'https://cseducators.stackexchange.com/tags/java/info', '200', 'Podaci o tagu.'],
                   "Preusmjeravanje na već postojeće pitanje": [88, 'https://cseducators.stackexchange.com/questions/88', 'https://cseducators.stackexchange.com/questions/69/how-can-i-integrate-teaching-source-code-control-git-mercurial-etc-into-my-int/88#88', '200', 'Podaci o već postojećem pitanju.'],
                   "Preusmjeravanje na već izbrisano pitanje": [3400, 'https://cseducators.stackexchange.com/questions/3400', 'https://cseducators.stackexchange.com/questions/3397/how-to-setup-python-to-repr-string-literals-with-double-quotes-when-possible/3400', '404', 'Stranica ne postoji.']},
                  ["id", "link", "get_link", "status_code", "message"])

# %%
question_classification
# Out:
#                                            Nepostojeće pitanje  ...           Preusmjeravanje na već izbrisano pitanje
# id                                                           0  ...                                               3400
# link         https://cseducators.stackexchange.com/questions/0  ...  https://cseducators.stackexchange.com/question...
# get_link     https://cseducators.stackexchange.com/questions/0  ...  https://cseducators.stackexchange.com/question...
# status_code                                                404  ...                                                404
# message                                   Stranica ne postoji.  ...                               Stranica ne postoji.
#
# [5 rows x 7 columns]

# %%
list_wiki = []
list_answers = []
list_questions = []

# %% [markdown]
# > ❗ Fokus je dohvatiti sva pitanja pa raspon id-jeva slijedi od 0 do last_question_id + 1
#
# > Budući plan je nadograditi program na način da se dohvaćaju svi odgovori, pitanja, tagovi i dr. 💡

# %%
#Kreiramo listu za sve podatke koje cemo spremati (wiki stranicu, stranicu sa odgovorima, stranicu sa pitanjima)

for i in range(0, int(last_question_id)+1):
    link = ('https://cseducators.stackexchange.com/questions/'+str(i))
    response = requests.get(link)
    soup = BeautifulSoup(response.text)

    get_link = soup.find("meta", property="og:url")["content"]
    tab_title = soup.find("title").text

    print("Status code:", response.status_code)

    question_existed = False

    #Slucaj kada ne postoji stranica
    if (response.status_code == 404):
      
      #Slucaj kada id ne postoji
      if (link == get_link):
        page_answer = re.sub(clean, '', str(soup.find("div",class_="fs-subheading mb24").find_all('p')[0]).replace("<p>","").replace("</p>",""))
        print("Id nepostojećeg pitanja:",i,"\nLink stranice:", get_link,"\nOdgovor stranice:", page_answer,"\n")

      #Slucaj kada je pitanje obrisano
      else:
        question_existed = True
        title = (get_link.split("/")[-1].replace("-"," ")).capitalize()
        
        if (title[-4:] != str(i)):
        
          info = " ".join(str(soup.find("div",class_="fs-subheading mb24").find_all('p')[0]).replace("<p>","").replace("</p>","").split(" ")[:3])
          info_comment = (soup.find("span",class_="revision-comment").text)
          print("Id izbrisanog pitanja:",i,"\nLink stranice:",get_link,"\nNaslov pitanja koje je obrisano:",title,"\nObavijest o pitanju:",info,info_comment,"\nPitanje je postojalo: ", question_existed, "\n")
          
          question = [i, title, "-", "-", "-", "-", "-", "-", "-", "-", "-", "-", question_existed]
          list_questions.append(question)

        else:
          print("Id:", i, "\nPreusmjeravanje na pitanje s id koje je već izbrisano.")

    #Slucaj kada smo dobili podatak sa razlicitim id-em kojeg smo poslali
    else:

      if(link not in get_link):

        #Slucaj kada stranica koju smo dohvatili je wiki stranica
        if ("/tags/" in str(get_link)):
          print("Id wiki taga: ", i)

          title = (tab_title.split("'")[1]+ " "+tab_title.split("'")[2].split(" ")[1]+" "+tab_title.split("'")[2].split(" ")[2]).capitalize()
          info = str("".join([i.text for i in soup.find("div",class_="welovestackoverflow").find_all('p')])).strip()
          wiki = [i,title, info]

          #Spremamo sve naslove iz liste koji postoje te provjeravamo je li trenutni naslov vec postoji u listi
          wiki_titles = [i[1] for i in list_wiki]

          if (wiki[1] not in wiki_titles):
            list_wiki.append(wiki)

        else:
          #Slucaj kada smo dobili odgovor na pitanje
          print("Id odgovora na pitanje:", i)
          try:
            #Trazimo postoji li nase pitanje u podacima koje smo dobili i dohvacamo onda njegove podatke
            page_answer = soup.find("div", {"data-answerid":i})
            #Id pitanja
            id_question = get_link.split('/')[4]

            #Pokusavamo dohvatiti naslov pitanja(boldani dio teksta), a ako ga nema onda je None
            try:
              title = str(page_answer.find("div",class_="s-prose js-post-body").find("p").find("strong")).replace("<strong>","").replace("</strong>","")
            except AttributeError:
              title = "None"
            
            content = "".join([i.text for i in soup.find('div', {"id": "answer-"+str(i)}).find_all('div', class_="s-prose js-post-body")]).replace("\n", " ")

            #Pokusavamo dohvatiti id user-a (autora odgovora), a ako ga nema onda spremamo None
            try:
              user_id = page_answer.find("div",{"itemprop":"author"}).find("a")['href'].split('/')[2]
            except TypeError:
              user_id = "None"
            
            #datum kada je kreiran odgovor
            date = str(page_answer.find("span",class_="relativetime")["title"]).replace("Z","")
            
            #Broj vote-ova na odgovoru
            try:
              votes = page_answer.find("div", class_="js-vote-count flex--item d-flex fd-column ai-center fc-black-500 fs-title")["data-value"]
            except TypeError:
              votes = page_answer.find("div",class_="js-vote-count fs-title lh-md mb8 ta-center")["data-value"]

            answer = [i, title, content, user_id, date, votes, id_question]
            list_answers.append(answer)

          #Slucaj kada smo dobili pitanje koje vec postoji pod drugim id-em
          except AttributeError:
            id = get_link.split("/")[4]
            print("Poslani id", i ,"postoji već za pitanje sa id-em", id)

      #Slucaj kada smo dobili pitanje i sve njegove podatke
      else:
        print("Id pitanja:", i)
        
        title = "".join([i.text for i in soup.find('h1', class_="fs-headline1 ow-break-word mb8 flex--item fl1").find_all('a')])
        content = "".join([i.text for i in soup.find('div', class_="s-prose js-post-body").find_all('p')])
        created_at = ("".join([i['datetime'] for i in soup.find('div', class_="flex--item ws-nowrap mr16 mb8").find_all('time')])).replace("T"," ")

        #Dohvacamo user id, a ako ga nema onda postavljamo u None
        try:
          user_id = ("".join([i['href'] for i in soup.find('div', class_="post-signature owner flex--item").find(class_="user-details").find_all('a')])).split("/")[2]
        except IndexError:
          user_id = "None"
        views_count = ("".join([i for i in soup.find('div', class_="d-flex fw-wrap pb8 mb16 bb bc-black-075").find('div',class_="flex--item ws-nowrap mb8")['title']])).split(" ")[1]
        
        try:
          votes_count = "".join([i for i in soup.find('div', class_="js-vote-count flex--item d-flex fd-column ai-center fc-black-500 fs-title")['data-value']])
        except TypeError:
          votes_count = "".join([i for i in soup.find('div', class_="js-vote-count fs-title lh-md mb8 ta-center")['data-value']])

        #Dohvacamo broj bookmarks-a, a ukoliko ih nema onda spremamo 0
        try:
          bookmarks_count = "".join([i for i in soup.find('div', class_="js-bookmark-count mt4")['data-value']])
        except TypeError:
          bookmarks_count = "".join([i for i in soup.find('div', class_="js-bookmark-count mt4 d-none")])
          bookmarks_count = (0 if bookmarks_count == "" else 0)

        answers_count = "".join([i['data-answercount'] for i in soup.find('div', class_="answers-subheader d-flex ai-center mb8").find_all('h2')])
        tags = ("".join([(i.text+"\t") for i in soup.find('div', class_="d-flex ps-relative fw-wrap").find_all('a')])).split("\t")[:-1]
        comment_count = len(([i for i in soup.find("div",class_="post-layout").find("ul",class_="comments-list js-comments-list").find_all("li")]))+int([soup.find("div",class_="post-layout").find('ul',class_="comments-list js-comments-list")["data-remaining-comments-count"]][0])
        is_answered = (True if int(answers_count) > 0 else False)
        question = [i, title, content, created_at, user_id, is_answered, views_count, votes_count, bookmarks_count, answers_count, tags, comment_count, question_existed]
        list_questions.append(question)

    if (i!=0 and i % 20 == 0):
      time.sleep(45)
# Out:
# Streaming output truncated to the last 5000 lines.
# Status code: 404
# Id izbrisanog pitanja: 5277
# Link stranice: https://cseducators.stackexchange.com/questions/5277/which-elective-should-i-take-next-semester-advanced-computer-architecture-or-in
# Naslov pitanja koje je obrisano: Which elective should i take next semester advanced computer architecture or in
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5278
# Link stranice: https://cseducators.stackexchange.com/questions/5278/which-is-easier-to-learn-perl-or-tcl
# Naslov pitanja koje je obrisano: Which is easier to learn perl or tcl
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5279
# Status code: 404
# Id: 5280
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id pitanja: 5281
# Status code: 200
# Id odgovora na pitanje: 5282
# Status code: 200
# Id odgovora na pitanje: 5283
# Status code: 404
# Id izbrisanog pitanja: 5284
# Link stranice: https://cseducators.stackexchange.com/questions/5284/what-is-a-data-craftman-in-the-data-sciences-world
# Naslov pitanja koje je obrisano: What is a data craftman in the data sciences world
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id: 5285
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id odgovora na pitanje: 5286
# Status code: 200
# Id odgovora na pitanje: 5287
# Status code: 200
# Id pitanja: 5288
# Status code: 200
# Id odgovora na pitanje: 5289
# Status code: 200
# Id odgovora na pitanje: 5290
# Status code: 200
# Id odgovora na pitanje: 5291
# Poslani id 5291 postoji već za pitanje sa id-em 5204
# Status code: 200
# Id odgovora na pitanje: 5292
# Poslani id 5292 postoji već za pitanje sa id-em 5242
# Status code: 404
# Id izbrisanog pitanja: 5293
# Link stranice: https://cseducators.stackexchange.com/questions/5293/phone-maintenance-course
# Naslov pitanja koje je obrisano: Phone maintenance course
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5294
# Link stranice: https://cseducators.stackexchange.com/questions/5294/functional-programming-in-javascript
# Naslov pitanja koje je obrisano: Functional programming in javascript
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5295
# Status code: 200
# Id odgovora na pitanje: 5296
# Status code: 404
# Id izbrisanog pitanja: 5297
# Link stranice: https://cseducators.stackexchange.com/questions/5297/how-to-continuously-improve-as-a-developer
# Naslov pitanja koje je obrisano: How to continuously improve as a developer
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5298
# Status code: 200
# Id odgovora na pitanje: 5299
# Status code: 200
# Id odgovora na pitanje: 5300
# Status code: 404
# Id izbrisanog pitanja: 5301
# Link stranice: https://cseducators.stackexchange.com/questions/5301/tools-and-methods-to-teach-remotely
# Naslov pitanja koje je obrisano: Tools and methods to teach remotely
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5302
# Status code: 200
# Id odgovora na pitanje: 5303
# Status code: 200
# Id odgovora na pitanje: 5304
# Status code: 200
# Id odgovora na pitanje: 5305
# Status code: 200
# Id pitanja: 5306
# Status code: 200
# Id odgovora na pitanje: 5307
# Status code: 200
# Id odgovora na pitanje: 5308
# Status code: 200
# Id odgovora na pitanje: 5309
# Status code: 200
# Id odgovora na pitanje: 5310
# Poslani id 5310 postoji već za pitanje sa id-em 5262
# Status code: 404
# Id izbrisanog pitanja: 5311
# Link stranice: https://cseducators.stackexchange.com/questions/5311/college-quality-on-line-it-classes
# Naslov pitanja koje je obrisano: College quality on line it classes
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5312
# Status code: 200
# Id odgovora na pitanje: 5313
# Status code: 200
# Id odgovora na pitanje: 5314
# Status code: 200
# Id odgovora na pitanje: 5315
# Status code: 200
# Id odgovora na pitanje: 5316
# Status code: 200
# Id odgovora na pitanje: 5317
# Status code: 404
# Id izbrisanog pitanja: 5318
# Link stranice: https://cseducators.stackexchange.com/questions/5318/vector-and-list
# Naslov pitanja koje je obrisano: Vector and list
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5319
# Status code: 200
# Id pitanja: 5320
# Status code: 200
# Id odgovora na pitanje: 5321
# Status code: 200
# Id odgovora na pitanje: 5322
# Status code: 200
# Id odgovora na pitanje: 5323
# Status code: 404
# Id izbrisanog pitanja: 5324
# Link stranice: https://cseducators.stackexchange.com/questions/5324/exercise-tracker
# Naslov pitanja koje je obrisano: Exercise tracker
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5325
# Status code: 200
# Id pitanja: 5326
# Status code: 200
# Id odgovora na pitanje: 5327
# Status code: 200
# Id odgovora na pitanje: 5328
# Status code: 200
# Id odgovora na pitanje: 5329
# Status code: 200
# Id odgovora na pitanje: 5330
# Status code: 200
# Id odgovora na pitanje: 5331
# Status code: 404
# Id izbrisanog pitanja: 5332
# Link stranice: https://cseducators.stackexchange.com/questions/5332/a-student-who-had-completed-his-bsc-on-eee-will-he-can-to-complete-his-msc-on-c
# Naslov pitanja koje je obrisano: A student who had completed his bsc on eee will he can to complete his msc on c
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5333
# Status code: 200
# Id odgovora na pitanje: 5334
# Status code: 200
# Id odgovora na pitanje: 5335
# Status code: 404
# Id izbrisanog pitanja: 5336
# Link stranice: https://cseducators.stackexchange.com/questions/5336/how-to-split-a-string-without-using-split-function-python-3-7
# Naslov pitanja koje je obrisano: How to split a string without using split function python 3 7
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5337
# Status code: 200
# Id odgovora na pitanje: 5338
# Status code: 200
# Id pitanja: 5339
# Status code: 200
# Id odgovora na pitanje: 5340
# Status code: 200
# Id pitanja: 5341
# Status code: 200
# Id odgovora na pitanje: 5342
# Status code: 200
# Id odgovora na pitanje: 5343
# Status code: 200
# Id odgovora na pitanje: 5344
# Status code: 200
# Id odgovora na pitanje: 5345
# Status code: 200
# Id odgovora na pitanje: 5346
# Status code: 200
# Id odgovora na pitanje: 5347
# Status code: 200
# Id pitanja: 5348
# Status code: 200
# Id odgovora na pitanje: 5349
# Status code: 200
# Id odgovora na pitanje: 5350
# Status code: 200
# Id odgovora na pitanje: 5351
# Status code: 200
# Id odgovora na pitanje: 5352
# Status code: 200
# Id odgovora na pitanje: 5353
# Status code: 200
# Id odgovora na pitanje: 5354
# Status code: 200
# Id pitanja: 5355
# Status code: 200
# Id odgovora na pitanje: 5356
# Status code: 200
# Id odgovora na pitanje: 5357
# Status code: 200
# Id pitanja: 5358
# Status code: 200
# Id odgovora na pitanje: 5359
# Status code: 200
# Id odgovora na pitanje: 5360
# Status code: 200
# Id odgovora na pitanje: 5361
# Status code: 200
# Id odgovora na pitanje: 5362
# Status code: 200
# Id odgovora na pitanje: 5363
# Status code: 200
# Id odgovora na pitanje: 5364
# Status code: 200
# Id odgovora na pitanje: 5365
# Status code: 404
# Id izbrisanog pitanja: 5366
# Link stranice: https://cseducators.stackexchange.com/questions/5366/whats-1-25-in-binary-2s-complement-form
# Naslov pitanja koje je obrisano: Whats 1 25 in binary 2s complement form
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5367
# Status code: 404
# Id izbrisanog pitanja: 5368
# Link stranice: https://cseducators.stackexchange.com/questions/5368/open-source-platform-management-suggest
# Naslov pitanja koje je obrisano: Open source platform management suggest
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5369
# Link stranice: https://cseducators.stackexchange.com/questions/5369/how-to-learn-basics-of-git
# Naslov pitanja koje je obrisano: How to learn basics of git
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id: 5370
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id pitanja: 5371
# Status code: 200
# Id odgovora na pitanje: 5372
# Status code: 200
# Id pitanja: 5373
# Status code: 200
# Id odgovora na pitanje: 5374
# Status code: 200
# Id odgovora na pitanje: 5375
# Status code: 200
# Id odgovora na pitanje: 5376
# Status code: 200
# Id odgovora na pitanje: 5377
# Status code: 200
# Id odgovora na pitanje: 5378
# Status code: 200
# Id pitanja: 5379
# Status code: 404
# Id izbrisanog pitanja: 5380
# Link stranice: https://cseducators.stackexchange.com/questions/5380/agile-ba-business-analyst-exam
# Naslov pitanja koje je obrisano: Agile ba business analyst exam
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5381
# Status code: 200
# Id odgovora na pitanje: 5382
# Status code: 200
# Id odgovora na pitanje: 5383
# Status code: 404
# Id: 5384
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 404
# Id izbrisanog pitanja: 5385
# Link stranice: https://cseducators.stackexchange.com/questions/5385/educational-simulations-that-teach-ideas-in-computer-science
# Naslov pitanja koje je obrisano: Educational simulations that teach ideas in computer science
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5386
# Status code: 200
# Id odgovora na pitanje: 5387
# Status code: 404
# Id: 5388
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id odgovora na pitanje: 5389
# Status code: 200
# Id odgovora na pitanje: 5390
# Poslani id 5390 postoji već za pitanje sa id-em 1099
# Status code: 200
# Id odgovora na pitanje: 5391
# Status code: 404
# Id izbrisanog pitanja: 5392
# Link stranice: https://cseducators.stackexchange.com/questions/5392/write-a-program-to-write-some-lines
# Naslov pitanja koje je obrisano: Write a program to write some lines
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5393
# Status code: 200
# Id pitanja: 5394
# Status code: 200
# Id odgovora na pitanje: 5395
# Status code: 200
# Id odgovora na pitanje: 5396
# Poslani id 5396 postoji već za pitanje sa id-em 5394
# Status code: 200
# Id odgovora na pitanje: 5397
# Status code: 404
# Id izbrisanog pitanja: 5398
# Link stranice: https://cseducators.stackexchange.com/questions/5398/bbjnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# Naslov pitanja koje je obrisano: Bbjnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5399
# Status code: 200
# Id odgovora na pitanje: 5400
# Status code: 200
# Id odgovora na pitanje: 5401
# Status code: 200
# Id odgovora na pitanje: 5402
# Status code: 200
# Id pitanja: 5403
# Status code: 200
# Id odgovora na pitanje: 5404
# Status code: 200
# Id odgovora na pitanje: 5405
# Status code: 200
# Id odgovora na pitanje: 5406
# Status code: 200
# Id odgovora na pitanje: 5407
# Status code: 200
# Id pitanja: 5408
# Status code: 200
# Id pitanja: 5409
# Status code: 200
# Id odgovora na pitanje: 5410
# Status code: 200
# Id pitanja: 5411
# Status code: 200
# Id odgovora na pitanje: 5412
# Status code: 404
# Id izbrisanog pitanja: 5413
# Link stranice: https://cseducators.stackexchange.com/questions/5413/what-do-i-need-to-know
# Naslov pitanja koje je obrisano: What do i need to know
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5414
# Status code: 200
# Id odgovora na pitanje: 5415
# Status code: 200
# Id odgovora na pitanje: 5416
# Status code: 200
# Id pitanja: 5417
# Status code: 200
# Id odgovora na pitanje: 5418
# Status code: 200
# Id odgovora na pitanje: 5419
# Status code: 200
# Id odgovora na pitanje: 5420
# Poslani id 5420 postoji već za pitanje sa id-em 125103
# Status code: 200
# Id pitanja: 5421
# Status code: 200
# Id pitanja: 5422
# Status code: 200
# Id odgovora na pitanje: 5423
# Status code: 200
# Id odgovora na pitanje: 5424
# Status code: 200
# Id odgovora na pitanje: 5425
# Status code: 200
# Id odgovora na pitanje: 5426
# Status code: 200
# Id odgovora na pitanje: 5427
# Status code: 200
# Id odgovora na pitanje: 5428
# Status code: 200
# Id odgovora na pitanje: 5429
# Status code: 200
# Id odgovora na pitanje: 5430
# Status code: 200
# Id odgovora na pitanje: 5431
# Status code: 200
# Id odgovora na pitanje: 5432
# Status code: 200
# Id pitanja: 5433
# Status code: 200
# Id odgovora na pitanje: 5434
# Status code: 200
# Id odgovora na pitanje: 5435
# Status code: 200
# Id odgovora na pitanje: 5436
# Status code: 200
# Id odgovora na pitanje: 5437
# Status code: 200
# Id odgovora na pitanje: 5438
# Status code: 200
# Id odgovora na pitanje: 5439
# Status code: 200
# Id odgovora na pitanje: 5440
# Poslani id 5440 postoji već za pitanje sa id-em 5417
# Status code: 404
# Id izbrisanog pitanja: 5441
# Link stranice: https://cseducators.stackexchange.com/questions/5441/usage-of-modal-expected-error-in-python
# Naslov pitanja koje je obrisano: Usage of modal expected error in python
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5442
# Status code: 200
# Id odgovora na pitanje: 5443
# Status code: 200
# Id odgovora na pitanje: 5444
# Status code: 200
# Id pitanja: 5445
# Status code: 200
# Id odgovora na pitanje: 5446
# Status code: 200
# Id odgovora na pitanje: 5447
# Status code: 200
# Id pitanja: 5448
# Status code: 200
# Id odgovora na pitanje: 5449
# Status code: 200
# Id odgovora na pitanje: 5450
# Status code: 200
# Id pitanja: 5451
# Status code: 200
# Id odgovora na pitanje: 5452
# Status code: 200
# Id odgovora na pitanje: 5453
# Status code: 200
# Id odgovora na pitanje: 5454
# Status code: 200
# Id odgovora na pitanje: 5455
# Status code: 200
# Id pitanja: 5456
# Status code: 200
# Id odgovora na pitanje: 5457
# Status code: 200
# Id odgovora na pitanje: 5458
# Status code: 200
# Id odgovora na pitanje: 5459
# Status code: 200
# Id odgovora na pitanje: 5460
# Status code: 200
# Id pitanja: 5461
# Status code: 404
# Id izbrisanog pitanja: 5462
# Link stranice: https://cseducators.stackexchange.com/questions/5462/how-to-open-enc-file
# Naslov pitanja koje je obrisano: How to open enc file
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id: 5463
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id odgovora na pitanje: 5464
# Status code: 404
# Id izbrisanog pitanja: 5465
# Link stranice: https://cseducators.stackexchange.com/questions/5465/what-is-difference-between-buffer-and-ram
# Naslov pitanja koje je obrisano: What is difference between buffer and ram
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5466
# Status code: 404
# Id izbrisanog pitanja: 5467
# Link stranice: https://cseducators.stackexchange.com/questions/5467/computer-for-programming
# Naslov pitanja koje je obrisano: Computer for programming
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5468
# Status code: 200
# Id odgovora na pitanje: 5469
# Status code: 200
# Id pitanja: 5470
# Status code: 200
# Id odgovora na pitanje: 5471
# Status code: 200
# Id odgovora na pitanje: 5472
# Poslani id 5472 postoji već za pitanje sa id-em 5433
# Status code: 200
# Id odgovora na pitanje: 5473
# Poslani id 5473 postoji već za pitanje sa id-em 5470
# Status code: 200
# Id odgovora na pitanje: 5474
# Status code: 404
# Id izbrisanog pitanja: 5475
# Link stranice: https://cseducators.stackexchange.com/questions/5475/sharing-resources-with-others-via-the-web
# Naslov pitanja koje je obrisano: Sharing resources with others via the web
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5476
# Status code: 200
# Id odgovora na pitanje: 5477
# Status code: 200
# Id odgovora na pitanje: 5478
# Status code: 404
# Id izbrisanog pitanja: 5479
# Link stranice: https://cseducators.stackexchange.com/questions/5479/the-functioning-of-modern-computers-are-extremely-complex
# Naslov pitanja koje je obrisano: The functioning of modern computers are extremely complex
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5480
# Status code: 200
# Id pitanja: 5481
# Status code: 200
# Id odgovora na pitanje: 5482
# Status code: 200
# Id pitanja: 5483
# Status code: 200
# Id odgovora na pitanje: 5484
# Status code: 200
# Id odgovora na pitanje: 5485
# Status code: 200
# Id odgovora na pitanje: 5486
# Status code: 404
# Id izbrisanog pitanja: 5487
# Link stranice: https://cseducators.stackexchange.com/questions/5487/looking-for-collaborations-for-open-source-e-teaching
# Naslov pitanja koje je obrisano: Looking for collaborations for open source e teaching
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5488
# Status code: 404
# Id izbrisanog pitanja: 5489
# Link stranice: https://cseducators.stackexchange.com/questions/5489/feedback-on-professional-development-curriculum
# Naslov pitanja koje je obrisano: Feedback on professional development curriculum
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5490
# Status code: 404
# Id izbrisanog pitanja: 5491
# Link stranice: https://cseducators.stackexchange.com/questions/5491/writing-letter-of-support-for-h1-visa-applicant
# Naslov pitanja koje je obrisano: Writing letter of support for h1 visa applicant
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5492
# Status code: 200
# Id odgovora na pitanje: 5493
# Status code: 200
# Id odgovora na pitanje: 5494
# Status code: 200
# Id odgovora na pitanje: 5495
# Status code: 404
# Id izbrisanog pitanja: 5496
# Link stranice: https://cseducators.stackexchange.com/questions/5496/my-brother-is-learing-c-in-2019
# Naslov pitanja koje je obrisano: My brother is learing c in 2019
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5497
# Status code: 200
# Id odgovora na pitanje: 5498
# Status code: 200
# Id odgovora na pitanje: 5499
# Status code: 404
# Id izbrisanog pitanja: 5500
# Link stranice: https://cseducators.stackexchange.com/questions/5500/i-have-questions-about-cobol-for-my-studies-to-make-a-decision
# Naslov pitanja koje je obrisano: I have questions about cobol for my studies to make a decision
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5501
# Status code: 200
# Id odgovora na pitanje: 5502
# Status code: 404
# Id nepostojećeg pitanja: 5503
# Link stranice: https://cseducators.stackexchange.com/questions/5503
# Odgovor stranice: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation. Please refer to the help center for possible explanations why a question might be removed.
#
# Status code: 200
# Id odgovora na pitanje: 5504
# Status code: 404
# Id: 5505
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id odgovora na pitanje: 5506
# Status code: 404
# Id izbrisanog pitanja: 5507
# Link stranice: https://cseducators.stackexchange.com/questions/5507/how-is-used-python-by-company
# Naslov pitanja koje je obrisano: How is used python by company
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5508
# Status code: 200
# Id odgovora na pitanje: 5509
# Status code: 200
# Id odgovora na pitanje: 5510
# Status code: 200
# Id pitanja: 5511
# Status code: 200
# Id odgovora na pitanje: 5512
# Poslani id 5512 postoji već za pitanje sa id-em 349
# Status code: 404
# Id izbrisanog pitanja: 5513
# Link stranice: https://cseducators.stackexchange.com/questions/5513/ms-office-2016-help-problem
# Naslov pitanja koje je obrisano: Ms office 2016 help problem
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5514
# Link stranice: https://cseducators.stackexchange.com/questions/5514/details-about-learning-hadoop-big-data
# Naslov pitanja koje je obrisano: Details about learning hadoop big data
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5515
# Status code: 200
# Id pitanja: 5516
# Status code: 200
# Id odgovora na pitanje: 5517
# Status code: 200
# Id odgovora na pitanje: 5518
# Status code: 200
# Id pitanja: 5519
# Status code: 200
# Id odgovora na pitanje: 5520
# Status code: 200
# Id odgovora na pitanje: 5521
# Status code: 200
# Id odgovora na pitanje: 5522
# Status code: 200
# Id pitanja: 5523
# Status code: 200
# Id odgovora na pitanje: 5524
# Status code: 404
# Id izbrisanog pitanja: 5525
# Link stranice: https://cseducators.stackexchange.com/questions/5525/is-getchar-functon-work-in-integer-type-data-in-c-programming
# Naslov pitanja koje je obrisano: Is getchar functon work in integer type data in c programming
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5526
# Poslani id 5526 postoji već za pitanje sa id-em 5523
# Status code: 200
# Id pitanja: 5527
# Status code: 200
# Id odgovora na pitanje: 5528
# Status code: 200
# Id odgovora na pitanje: 5529
# Status code: 404
# Id izbrisanog pitanja: 5530
# Link stranice: https://cseducators.stackexchange.com/questions/5530/how-to-make-code-more-efficient
# Naslov pitanja koje je obrisano: How to make code more efficient
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5531
# Status code: 200
# Id odgovora na pitanje: 5532
# Status code: 200
# Id odgovora na pitanje: 5533
# Status code: 404
# Id izbrisanog pitanja: 5534
# Link stranice: https://cseducators.stackexchange.com/questions/5534/cannot-implement-ascending-sorting-algorithm-into-machine-code-for-mc6800
# Naslov pitanja koje je obrisano: Cannot implement ascending sorting algorithm into machine code for mc6800
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5535
# Status code: 404
# Id izbrisanog pitanja: 5536
# Link stranice: https://cseducators.stackexchange.com/questions/5536/is-arraylist-is-better-than-array
# Naslov pitanja koje je obrisano: Is arraylist is better than array
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5537
# Link stranice: https://cseducators.stackexchange.com/questions/5537/how-to-print-integer-on-stdout-in-armsim
# Naslov pitanja koje je obrisano: How to print integer on stdout in armsim
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5538
# Status code: 404
# Id izbrisanog pitanja: 5539
# Link stranice: https://cseducators.stackexchange.com/questions/5539/the-best-at-technologies
# Naslov pitanja koje je obrisano: The best at technologies
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5540
# Poslani id 5540 postoji već za pitanje sa id-em 104
# Status code: 200
# Id odgovora na pitanje: 5541
# Status code: 200
# Id pitanja: 5542
# Status code: 200
# Id odgovora na pitanje: 5543
# Status code: 200
# Id odgovora na pitanje: 5544
# Status code: 404
# Id izbrisanog pitanja: 5545
# Link stranice: https://cseducators.stackexchange.com/questions/5545/who-makes-the-best-anti-virus-program-without-complications
# Naslov pitanja koje je obrisano: Who makes the best anti virus program without complications
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5546
# Status code: 404
# Id izbrisanog pitanja: 5547
# Link stranice: https://cseducators.stackexchange.com/questions/5547/can-i-reboot-windows-10-to-7-if-my-two-local-drives-except-for-the-c-drive-are-e
# Naslov pitanja koje je obrisano: Can i reboot windows 10 to 7 if my two local drives except for the c drive are e
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5548
# Status code: 404
# Id izbrisanog pitanja: 5549
# Link stranice: https://cseducators.stackexchange.com/questions/5549/what-are-the-advantages-of-data-dictionary-as-applied-in-computer-system-analysi
# Naslov pitanja koje je obrisano: What are the advantages of data dictionary as applied in computer system analysi
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5550
# Link stranice: https://cseducators.stackexchange.com/questions/5550/what-is-the-difference-between-c-and-c
# Naslov pitanja koje je obrisano: What is the difference between c and c
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5551
# Status code: 200
# Id odgovora na pitanje: 5552
# Status code: 200
# Id odgovora na pitanje: 5553
# Status code: 404
# Id izbrisanog pitanja: 5554
# Link stranice: https://cseducators.stackexchange.com/questions/5554/how-to-become-good-in-object-oriented-programming
# Naslov pitanja koje je obrisano: How to become good in object oriented programming
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5555
# Link stranice: https://cseducators.stackexchange.com/questions/5555/best-language-for-student-studying-criminal-justice
# Naslov pitanja koje je obrisano: Best language for student studying criminal justice
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id: 5556
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id odgovora na pitanje: 5557
# Status code: 200
# Id pitanja: 5558
# Status code: 200
# Id odgovora na pitanje: 5559
# Status code: 404
# Id izbrisanog pitanja: 5560
# Link stranice: https://cseducators.stackexchange.com/questions/5560/image-processing-course-for-software-engineering
# Naslov pitanja koje je obrisano: Image processing course for software engineering
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5561
# Status code: 200
# Id odgovora na pitanje: 5562
# Status code: 200
# Id odgovora na pitanje: 5563
# Status code: 200
# Id odgovora na pitanje: 5564
# Status code: 200
# Id odgovora na pitanje: 5565
# Status code: 200
# Id pitanja: 5566
# Status code: 200
# Id odgovora na pitanje: 5567
# Status code: 200
# Id odgovora na pitanje: 5568
# Status code: 200
# Id pitanja: 5569
# Status code: 200
# Id odgovora na pitanje: 5570
# Status code: 404
# Id izbrisanog pitanja: 5571
# Link stranice: https://cseducators.stackexchange.com/questions/5571/reflexive-and-antisymmetric-have-same-things-in-some-cases
# Naslov pitanja koje je obrisano: Reflexive and antisymmetric have same things in some cases
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id wiki taga:  5572
# Status code: 200
# Id wiki taga:  5573
# Status code: 200
# Id odgovora na pitanje: 5574
# Status code: 200
# Id pitanja: 5575
# Status code: 200
# Id pitanja: 5576
# Status code: 200
# Id odgovora na pitanje: 5577
# Status code: 404
# Id izbrisanog pitanja: 5578
# Link stranice: https://cseducators.stackexchange.com/questions/5578/what-is-the-main-difference-between-direct-or-indirect-inheritance-in-java
# Naslov pitanja koje je obrisano: What is the main difference between direct or indirect inheritance in java
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5579
# Status code: 200
# Id odgovora na pitanje: 5580
# Status code: 200
# Id odgovora na pitanje: 5581
# Status code: 200
# Id odgovora na pitanje: 5582
# Status code: 200
# Id odgovora na pitanje: 5583
# Status code: 200
# Id odgovora na pitanje: 5584
# Status code: 200
# Id odgovora na pitanje: 5585
# Status code: 200
# Id odgovora na pitanje: 5586
# Status code: 200
# Id odgovora na pitanje: 5587
# Status code: 200
# Id odgovora na pitanje: 5588
# Status code: 404
# Id nepostojećeg pitanja: 5589
# Link stranice: https://cseducators.stackexchange.com/questions/5589
# Odgovor stranice: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation. Please refer to the help center for possible explanations why a question might be removed.
#
# Status code: 200
# Id odgovora na pitanje: 5590
# Poslani id 5590 postoji već za pitanje sa id-em 5579
# Status code: 200
# Id odgovora na pitanje: 5591
# Status code: 200
# Id odgovora na pitanje: 5592
# Status code: 200
# Id odgovora na pitanje: 5593
# Status code: 404
# Id izbrisanog pitanja: 5594
# Link stranice: https://cseducators.stackexchange.com/questions/5594/remove-elements-of-array-and-and-product-of-two-sides-to-score-how-to-maximize-t
# Naslov pitanja koje je obrisano: Remove elements of array and and product of two sides to score how to maximize t
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5595
# Status code: 200
# Id odgovora na pitanje: 5596
# Status code: 200
# Id odgovora na pitanje: 5597
# Status code: 200
# Id odgovora na pitanje: 5598
# Status code: 200
# Id pitanja: 5599
# Status code: 200
# Id odgovora na pitanje: 5600
# Status code: 200
# Id odgovora na pitanje: 5601
# Status code: 200
# Id odgovora na pitanje: 5602
# Status code: 200
# Id pitanja: 5603
# Status code: 200
# Id odgovora na pitanje: 5604
# Status code: 200
# Id odgovora na pitanje: 5605
# Status code: 200
# Id pitanja: 5606
# Status code: 200
# Id pitanja: 5607
# Status code: 200
# Id odgovora na pitanje: 5608
# Status code: 200
# Id odgovora na pitanje: 5609
# Status code: 200
# Id odgovora na pitanje: 5610
# Status code: 200
# Id odgovora na pitanje: 5611
# Status code: 200
# Id odgovora na pitanje: 5612
# Status code: 200
# Id odgovora na pitanje: 5613
# Status code: 200
# Id pitanja: 5614
# Status code: 200
# Id odgovora na pitanje: 5615
# Status code: 200
# Id odgovora na pitanje: 5616
# Status code: 200
# Id pitanja: 5617
# Status code: 200
# Id odgovora na pitanje: 5618
# Status code: 200
# Id pitanja: 5619
# Status code: 200
# Id odgovora na pitanje: 5620
# Status code: 200
# Id odgovora na pitanje: 5621
# Status code: 200
# Id odgovora na pitanje: 5622
# Status code: 404
# Id izbrisanog pitanja: 5623
# Link stranice: https://cseducators.stackexchange.com/questions/5623/how-to-create-a-code-that-writes-every-time-a-picture-in-a-video-switches
# Naslov pitanja koje je obrisano: How to create a code that writes every time a picture in a video switches
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5624
# Status code: 404
# Id nepostojećeg pitanja: 5625
# Link stranice: https://cseducators.stackexchange.com/questions/5625
# Odgovor stranice: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation. Please refer to the help center for possible explanations why a question might be removed.
#
# Status code: 200
# Id pitanja: 5626
# Status code: 200
# Id pitanja: 5627
# Status code: 200
# Id odgovora na pitanje: 5628
# Status code: 200
# Id pitanja: 5629
# Status code: 200
# Id odgovora na pitanje: 5630
# Status code: 200
# Id odgovora na pitanje: 5631
# Status code: 200
# Id odgovora na pitanje: 5632
# Status code: 200
# Id pitanja: 5633
# Status code: 200
# Id odgovora na pitanje: 5634
# Status code: 200
# Id odgovora na pitanje: 5635
# Status code: 200
# Id odgovora na pitanje: 5636
# Status code: 200
# Id odgovora na pitanje: 5637
# Status code: 200
# Id odgovora na pitanje: 5638
# Status code: 200
# Id odgovora na pitanje: 5639
# Status code: 200
# Id odgovora na pitanje: 5640
# Status code: 200
# Id odgovora na pitanje: 5641
# Status code: 200
# Id odgovora na pitanje: 5642
# Status code: 200
# Id odgovora na pitanje: 5643
# Status code: 200
# Id pitanja: 5644
# Status code: 200
# Id odgovora na pitanje: 5645
# Status code: 200
# Id odgovora na pitanje: 5646
# Status code: 200
# Id odgovora na pitanje: 5647
# Status code: 200
# Id odgovora na pitanje: 5648
# Status code: 200
# Id odgovora na pitanje: 5649
# Status code: 200
# Id odgovora na pitanje: 5650
# Status code: 200
# Id odgovora na pitanje: 5651
# Status code: 200
# Id odgovora na pitanje: 5652
# Status code: 200
# Id pitanja: 5653
# Status code: 200
# Id odgovora na pitanje: 5654
# Status code: 200
# Id odgovora na pitanje: 5655
# Status code: 200
# Id odgovora na pitanje: 5656
# Poslani id 5656 postoji već za pitanje sa id-em 5644
# Status code: 200
# Id odgovora na pitanje: 5657
# Status code: 200
# Id pitanja: 5658
# Status code: 200
# Id odgovora na pitanje: 5659
# Status code: 200
# Id pitanja: 5660
# Status code: 200
# Id odgovora na pitanje: 5661
# Status code: 200
# Id odgovora na pitanje: 5662
# Status code: 200
# Id odgovora na pitanje: 5663
# Status code: 200
# Id odgovora na pitanje: 5664
# Status code: 200
# Id odgovora na pitanje: 5665
# Status code: 200
# Id odgovora na pitanje: 5666
# Status code: 200
# Id odgovora na pitanje: 5667
# Status code: 200
# Id odgovora na pitanje: 5668
# Poslani id 5668 postoji već za pitanje sa id-em 5606
# Status code: 404
# Id izbrisanog pitanja: 5669
# Link stranice: https://cseducators.stackexchange.com/questions/5669/how-to-teach-programming-language-to-the-school-students
# Naslov pitanja koje je obrisano: How to teach programming language to the school students
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5670
# Link stranice: https://cseducators.stackexchange.com/questions/5670/oop-technical-test-vs-python-applicant
# Naslov pitanja koje je obrisano: Oop technical test vs python applicant
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5671
# Status code: 200
# Id odgovora na pitanje: 5672
# Status code: 404
# Id izbrisanog pitanja: 5673
# Link stranice: https://cseducators.stackexchange.com/questions/5673/teaching-the-difference-between-fundamentals-vs-extras
# Naslov pitanja koje je obrisano: Teaching the difference between fundamentals vs extras
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5674
# Status code: 200
# Id odgovora na pitanje: 5675
# Status code: 200
# Id odgovora na pitanje: 5676
# Status code: 200
# Id odgovora na pitanje: 5677
# Status code: 200
# Id odgovora na pitanje: 5678
# Status code: 200
# Id pitanja: 5679
# Status code: 200
# Id odgovora na pitanje: 5680
# Status code: 200
# Id odgovora na pitanje: 5681
# Poslani id 5681 postoji već za pitanje sa id-em 5671
# Status code: 200
# Id odgovora na pitanje: 5682
# Status code: 404
# Id izbrisanog pitanja: 5683
# Link stranice: https://cseducators.stackexchange.com/questions/5683/how-to-make-an-interactive-interface-in-android
# Naslov pitanja koje je obrisano: How to make an interactive interface in android
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5684
# Status code: 200
# Id odgovora na pitanje: 5685
# Status code: 404
# Id izbrisanog pitanja: 5686
# Link stranice: https://cseducators.stackexchange.com/questions/5686/how-can-i-design-the-sign-up-page-in-android
# Naslov pitanja koje je obrisano: How can i design the sign up page in android
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5687
# Status code: 200
# Id odgovora na pitanje: 5688
# Status code: 200
# Id odgovora na pitanje: 5689
# Status code: 200
# Id pitanja: 5690
# Status code: 200
# Id odgovora na pitanje: 5691
# Status code: 200
# Id odgovora na pitanje: 5692
# Status code: 200
# Id odgovora na pitanje: 5693
# Status code: 200
# Id odgovora na pitanje: 5694
# Status code: 200
# Id odgovora na pitanje: 5695
# Status code: 200
# Id odgovora na pitanje: 5696
# Status code: 200
# Id odgovora na pitanje: 5697
# Poslani id 5697 postoji već za pitanje sa id-em 5629
# Status code: 200
# Id odgovora na pitanje: 5698
# Status code: 200
# Id odgovora na pitanje: 5699
# Status code: 200
# Id odgovora na pitanje: 5700
# Status code: 404
# Id izbrisanog pitanja: 5701
# Link stranice: https://cseducators.stackexchange.com/questions/5701/what-is-actually-the-role-of-generation
# Naslov pitanja koje je obrisano: What is actually the role of generation
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5702
# Status code: 200
# Id odgovora na pitanje: 5703
# Status code: 200
# Id odgovora na pitanje: 5704
# Status code: 404
# Id izbrisanog pitanja: 5705
# Link stranice: https://cseducators.stackexchange.com/questions/5705/how-to-prepare-for-backlogs
# Naslov pitanja koje je obrisano: How to prepare for backlogs
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5706
# Status code: 200
# Id odgovora na pitanje: 5707
# Status code: 200
# Id odgovora na pitanje: 5708
# Status code: 200
# Id odgovora na pitanje: 5709
# Status code: 200
# Id odgovora na pitanje: 5710
# Status code: 200
# Id odgovora na pitanje: 5711
# Status code: 404
# Id izbrisanog pitanja: 5712
# Link stranice: https://cseducators.stackexchange.com/questions/5712/how-to-import-data-from-excel-to-database-in-asp-net
# Naslov pitanja koje je obrisano: How to import data from excel to database in asp net
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5713
# Status code: 200
# Id odgovora na pitanje: 5714
# Status code: 404
# Id izbrisanog pitanja: 5715
# Link stranice: https://cseducators.stackexchange.com/questions/5715/which-apis-are-used-to-communicate-between-android-and-server
# Naslov pitanja koje je obrisano: Which apis are used to communicate between android and server
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5716
# Status code: 200
# Id odgovora na pitanje: 5717
# Status code: 200
# Id odgovora na pitanje: 5718
# Status code: 200
# Id pitanja: 5719
# Status code: 200
# Id odgovora na pitanje: 5720
# Status code: 200
# Id odgovora na pitanje: 5721
# Status code: 200
# Id odgovora na pitanje: 5722
# Status code: 200
# Id odgovora na pitanje: 5723
# Status code: 200
# Id pitanja: 5724
# Status code: 200
# Id odgovora na pitanje: 5725
# Status code: 200
# Id odgovora na pitanje: 5726
# Status code: 200
# Id odgovora na pitanje: 5727
# Status code: 200
# Id pitanja: 5728
# Status code: 200
# Id odgovora na pitanje: 5729
# Status code: 200
# Id odgovora na pitanje: 5730
# Status code: 200
# Id odgovora na pitanje: 5731
# Status code: 200
# Id pitanja: 5732
# Status code: 200
# Id odgovora na pitanje: 5733
# Status code: 200
# Id odgovora na pitanje: 5734
# Status code: 200
# Id odgovora na pitanje: 5735
# Poslani id 5735 postoji već za pitanje sa id-em 330
# Status code: 200
# Id odgovora na pitanje: 5736
# Poslani id 5736 postoji već za pitanje sa id-em 5706
# Status code: 200
# Id odgovora na pitanje: 5737
# Status code: 200
# Id odgovora na pitanje: 5738
# Status code: 404
# Id izbrisanog pitanja: 5739
# Link stranice: https://cseducators.stackexchange.com/questions/5739/which-books-are-used-for-introductory-data-structures-courses-in-high-school-fre
# Naslov pitanja koje je obrisano: Which books are used for introductory data structures courses in high school fre
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 5740
# Link stranice: https://cseducators.stackexchange.com/questions/5740/get-support-by-canon-printer-helpline-uk
# Naslov pitanja koje je obrisano: Get support by canon printer helpline uk
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 5741
# Status code: 200
# Id odgovora na pitanje: 5742
# Status code: 200
# Id odgovora na pitanje: 5743
# Status code: 200
# Id odgovora na pitanje: 5744
# Status code: 200
# Id odgovora na pitanje: 5745
# Status code: 200
# Id pitanja: 5746
# Status code: 200
# Id odgovora na pitanje: 5747
# Poslani id 5747 postoji već za pitanje sa id-em 112
# Status code: 200
# Id pitanja: 5748
# Status code: 200
# Id odgovora na pitanje: 5749
# Status code: 200
# Id odgovora na pitanje: 5750
# Status code: 200
# Id odgovora na pitanje: 5751
# Status code: 200
# Id odgovora na pitanje: 5752
# Status code: 200
# Id odgovora na pitanje: 5753
# Status code: 200
# Id odgovora na pitanje: 5754
# Status code: 200
# Id pitanja: 5755
# Status code: 200
# Id odgovora na pitanje: 5756
# Poslani id 5756 postoji već za pitanje sa id-em 5755
# Status code: 200
# Id pitanja: 5757
# Status code: 200
# Id odgovora na pitanje: 5758
# Status code: 200
# Id odgovora na pitanje: 5759
# Status code: 200
# Id pitanja: 5760
# Status code: 200
# Id odgovora na pitanje: 5761
# Status code: 404
# Id izbrisanog pitanja: 5762
# Link stranice: https://cseducators.stackexchange.com/questions/5762/how-can-i-convert-json-file-to-pdf-file-in-c
# Naslov pitanja koje je obrisano: How can i convert json file to pdf file in c
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5763
# Status code: 200
# Id odgovora na pitanje: 5764
# Status code: 200
# Id pitanja: 5765
# Status code: 200
# Id odgovora na pitanje: 5766
# Status code: 404
# Id izbrisanog pitanja: 5767
# Link stranice: https://cseducators.stackexchange.com/questions/5767/career-learning-path
# Naslov pitanja koje je obrisano: Career learning path
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5768
# Status code: 200
# Id odgovora na pitanje: 5769
# Status code: 404
# Id izbrisanog pitanja: 5770
# Link stranice: https://cseducators.stackexchange.com/questions/5770/when-providing-programming-documentation-to-users-of-an-office-suite-software-d
# Naslov pitanja koje je obrisano: When providing programming documentation to users of an office suite software d
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 5771
# Status code: 200
# Id odgovora na pitanje: 5772
# Status code: 200
# Id odgovora na pitanje: 5773
# Status code: 200
# Id pitanja: 5774
# Status code: 200
# Id odgovora na pitanje: 5775
# Status code: 200
# Id odgovora na pitanje: 5776
# Status code: 200
# Id pitanja: 5777
# Status code: 200
# Id odgovora na pitanje: 5778
# Status code: 200
# Id odgovora na pitanje: 5779
# Status code: 200
# Id odgovora na pitanje: 5780
# Status code: 200
# Id odgovora na pitanje: 5781
# Status code: 200
# Id odgovora na pitanje: 5782
# Status code: 200
# Id odgovora na pitanje: 5783
# Status code: 200
# Id pitanja: 5784
# Status code: 200
# Id odgovora na pitanje: 5785
# Status code: 200
# Id odgovora na pitanje: 5786
# Status code: 200
# Id pitanja: 5787
# Status code: 200
# Id odgovora na pitanje: 5788
# Status code: 200
# Id odgovora na pitanje: 5789
# Status code: 200
# Id odgovora na pitanje: 5790
# Status code: 200
# Id odgovora na pitanje: 5791
# Status code: 200
# Id odgovora na pitanje: 5792
# Status code: 200
# Id odgovora na pitanje: 5793
# Status code: 200
# Id odgovora na pitanje: 5794
# Status code: 200
# Id odgovora na pitanje: 5795
# Status code: 200
# Id odgovora na pitanje: 5796
# Status code: 200
# Id pitanja: 5797
# Status code: 200
# Id odgovora na pitanje: 5798
# Status code: 200
# Id odgovora na pitanje: 5799
# Status code: 200
# Id odgovora na pitanje: 5800
# Status code: 200
# Id odgovora na pitanje: 5801
# Status code: 200
# Id odgovora na pitanje: 5802
# Poslani id 5802 postoji već za pitanje sa id-em 5728
# Status code: 200
# Id odgovora na pitanje: 5803
# Status code: 200
# Id pitanja: 5804
# Status code: 404
# Id izbrisanog pitanja: 5805
# Link stranice: https://cseducators.stackexchange.com/questions/5805/what-is-the-address-of-a-first-elementtop-most-element-present-in-singly-linke
# Naslov pitanja koje je obrisano: What is the address of a first elementtop most element present in singly linke
# ...
# Naslov pitanja koje je obrisano: Video lectures showing the way to solve recurrence relations using akra bazzi me
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7030
# Status code: 200
# Id pitanja: 7031
# Status code: 404
# Id izbrisanog pitanja: 7032
# Link stranice: https://cseducators.stackexchange.com/questions/7032/what-is-current-vaccination-regulation-for-international-students-for-us-univers
# Naslov pitanja koje je obrisano: What is current vaccination regulation for international students for us univers
# Obavijest o pitanju: This question was voluntarily removed by its author
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 7033
# Status code: 200
# Id odgovora na pitanje: 7034
# Status code: 200
# Id pitanja: 7035
# Status code: 200
# Id odgovora na pitanje: 7036
# Poslani id 7036 postoji već za pitanje sa id-em 7035
# Status code: 200
# Id pitanja: 7037
# Status code: 200
# Id odgovora na pitanje: 7038
# Status code: 404
# Id izbrisanog pitanja: 7039
# Link stranice: https://cseducators.stackexchange.com/questions/7039/what-is-exactly-a-full-stack-cloud-developer
# Naslov pitanja koje je obrisano: What is exactly a full stack cloud developer
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7040
# Status code: 200
# Id odgovora na pitanje: 7041
# Status code: 200
# Id odgovora na pitanje: 7042
# Poslani id 7042 postoji već za pitanje sa id-em 143480
# Status code: 404
# Id izbrisanog pitanja: 7043
# Link stranice: https://cseducators.stackexchange.com/questions/7043/finding-archived-course-webpages-on-the-internet
# Naslov pitanja koje je obrisano: Finding archived course webpages on the internet
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 7044
# Status code: 200
# Id pitanja: 7045
# Status code: 200
# Id odgovora na pitanje: 7046
# Status code: 200
# Id odgovora na pitanje: 7047
# Status code: 200
# Id odgovora na pitanje: 7048
# Status code: 200
# Id odgovora na pitanje: 7049
# Status code: 200
# Id odgovora na pitanje: 7050
# Status code: 200
# Id pitanja: 7051
# Status code: 200
# Id odgovora na pitanje: 7052
# Status code: 200
# Id odgovora na pitanje: 7053
# Poslani id 7053 postoji već za pitanje sa id-em 7044
# Status code: 200
# Id odgovora na pitanje: 7054
# Status code: 200
# Id odgovora na pitanje: 7055
# Status code: 404
# Id izbrisanog pitanja: 7056
# Link stranice: https://cseducators.stackexchange.com/questions/7056/oracle-virtualbox-needs-permission-and-i-dont-know-how-to-give-it
# Naslov pitanja koje je obrisano: Oracle virtualbox needs permission and i dont know how to give it
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7057
# Status code: 200
# Id pitanja: 7058
# Status code: 200
# Id odgovora na pitanje: 7059
# Status code: 404
# Id izbrisanog pitanja: 7060
# Link stranice: https://cseducators.stackexchange.com/questions/7060/how-to-choose-best-university-for-management-course
# Naslov pitanja koje je obrisano: How to choose best university for management course
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7061
# Status code: 404
# Id izbrisanog pitanja: 7062
# Link stranice: https://cseducators.stackexchange.com/questions/7062/how-do-i-insert-items-into-the-python-list-and-save-them-from-being-changed-afte
# Naslov pitanja koje je obrisano: How do i insert items into the python list and save them from being changed afte
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 7063
# Status code: 200
# Id odgovora na pitanje: 7064
# Status code: 200
# Id pitanja: 7065
# Status code: 200
# Id pitanja: 7066
# Status code: 200
# Id odgovora na pitanje: 7067
# Status code: 200
# Id pitanja: 7068
# Status code: 200
# Id odgovora na pitanje: 7069
# Status code: 200
# Id pitanja: 7070
# Status code: 404
# Id izbrisanog pitanja: 7071
# Link stranice: https://cseducators.stackexchange.com/questions/7071/what-is-the-code-here
# Naslov pitanja koje je obrisano: What is the code here
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id: 7072
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 404
# Id: 7073
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 404
# Id: 7074
# Preusmjeravanje na pitanje s id koje je već izbrisano.
# Status code: 200
# Id pitanja: 7075
# Status code: 200
# Id odgovora na pitanje: 7076
# Status code: 200
# Id odgovora na pitanje: 7077
# Status code: 404
# Id izbrisanog pitanja: 7078
# Link stranice: https://cseducators.stackexchange.com/questions/7078/how-to-fix-argument-problem-in-class-method-in-python
# Naslov pitanja koje je obrisano: How to fix argument problem in class method in python
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7079
# Status code: 200
# Id odgovora na pitanje: 7080
# Status code: 200
# Id pitanja: 7081
# Status code: 200
# Id pitanja: 7082
# Status code: 200
# Id odgovora na pitanje: 7083
# Status code: 200
# Id odgovora na pitanje: 7084
# Status code: 200
# Id pitanja: 7085
# Status code: 200
# Id odgovora na pitanje: 7086
# Status code: 200
# Id pitanja: 7087
# Status code: 200
# Id odgovora na pitanje: 7088
# Status code: 200
# Id odgovora na pitanje: 7089
# Status code: 200
# Id pitanja: 7090
# Status code: 200
# Id odgovora na pitanje: 7091
# Status code: 200
# Id odgovora na pitanje: 7092
# Status code: 200
# Id pitanja: 7093
# Status code: 200
# Id pitanja: 7094
# Status code: 200
# Id odgovora na pitanje: 7095
# Status code: 200
# Id odgovora na pitanje: 7096
# Status code: 200
# Id odgovora na pitanje: 7097
# Status code: 200
# Id odgovora na pitanje: 7098
# Poslani id 7098 postoji već za pitanje sa id-em 7094
# Status code: 404
# Id nepostojećeg pitanja: 7099
# Link stranice: https://cseducators.stackexchange.com/questions/7099
# Odgovor stranice: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation. Please refer to the help center for possible explanations why a question might be removed.
#
# Status code: 200
# Id odgovora na pitanje: 7100
# Status code: 200
# Id odgovora na pitanje: 7101
# Status code: 200
# Id odgovora na pitanje: 7102
# Status code: 200
# Id odgovora na pitanje: 7103
# Status code: 200
# Id pitanja: 7104
# Status code: 404
# Id izbrisanog pitanja: 7105
# Link stranice: https://cseducators.stackexchange.com/questions/7105/how-to-learn-theory-of-computation-and-automata-theory-as-a-student-who-is-bad-w
# Naslov pitanja koje je obrisano: How to learn theory of computation and automata theory as a student who is bad w
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 7106
# Status code: 200
# Id pitanja: 7107
# Status code: 200
# Id odgovora na pitanje: 7108
# Status code: 200
# Id odgovora na pitanje: 7109
# Status code: 200
# Id odgovora na pitanje: 7110
# Status code: 200
# Id odgovora na pitanje: 7111
# Status code: 200
# Id odgovora na pitanje: 7112
# Status code: 200
# Id pitanja: 7113
# Status code: 404
# Id izbrisanog pitanja: 7114
# Link stranice: https://cseducators.stackexchange.com/questions/7114/starting-with-open-source
# Naslov pitanja koje je obrisano: Starting with open source
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 404
# Id izbrisanog pitanja: 7115
# Link stranice: https://cseducators.stackexchange.com/questions/7115/if-in-exam-when-i-am-asked-how-to-make-cfg-or-pda-if-i-make-pda-and-convert-it
# Naslov pitanja koje je obrisano: If in exam when i am asked how to make cfg or pda if i make pda and convert it
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 7116
# Status code: 200
# Id odgovora na pitanje: 7117
# Status code: 200
# Id pitanja: 7118
# Status code: 200
# Id odgovora na pitanje: 7119
# Status code: 404
# Id izbrisanog pitanja: 7120
# Link stranice: https://cseducators.stackexchange.com/questions/7120/using-java-recordss-for-data-classes
# Naslov pitanja koje je obrisano: Using java recordss for data classes
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7121
# Status code: 200
# Id pitanja: 7122
# Status code: 200
# Id pitanja: 7123
# Status code: 200
# Id pitanja: 7124
# Status code: 200
# Id pitanja: 7125
# Status code: 200
# Id odgovora na pitanje: 7126
# Status code: 200
# Id odgovora na pitanje: 7127
# Status code: 200
# Id odgovora na pitanje: 7128
# Status code: 200
# Id odgovora na pitanje: 7129
# Status code: 404
# Id izbrisanog pitanja: 7130
# Link stranice: https://cseducators.stackexchange.com/questions/7130/time-complexity-of-while-statement
# Naslov pitanja koje je obrisano: Time complexity of while statement
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id pitanja: 7131
# Status code: 200
# Id odgovora na pitanje: 7132
# Status code: 200
# Id odgovora na pitanje: 7133
# Status code: 200
# Id odgovora na pitanje: 7134
# Status code: 200
# Id odgovora na pitanje: 7135
# Status code: 200
# Id odgovora na pitanje: 7136
# Status code: 200
# Id pitanja: 7137
# Status code: 200
# Id odgovora na pitanje: 7138
# Status code: 200
# Id odgovora na pitanje: 7139
# Status code: 200
# Id pitanja: 7140
# Status code: 200
# Id odgovora na pitanje: 7141
# Status code: 200
# Id pitanja: 7142
# Status code: 404
# Id izbrisanog pitanja: 7143
# Link stranice: https://cseducators.stackexchange.com/questions/7143/tn-2tn-21-then-tn
# Naslov pitanja koje je obrisano: Tn 2tn 21 then tn
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7144
# Status code: 200
# Id odgovora na pitanje: 7145
# Status code: 200
# Id odgovora na pitanje: 7146
# Status code: 200
# Id odgovora na pitanje: 7147
# Status code: 200
# Id pitanja: 7148
# Status code: 200
# Id odgovora na pitanje: 7149
# Status code: 200
# Id odgovora na pitanje: 7150
# Poslani id 7150 postoji već za pitanje sa id-em 7131
# Status code: 200
# Id pitanja: 7151
# Status code: 200
# Id odgovora na pitanje: 7152
# Status code: 200
# Id odgovora na pitanje: 7153
# Status code: 200
# Id pitanja: 7154
# Status code: 200
# Id pitanja: 7155
# Status code: 200
# Id odgovora na pitanje: 7156
# Status code: 200
# Id odgovora na pitanje: 7157
# Poslani id 7157 postoji već za pitanje sa id-em 7154
# Status code: 200
# Id odgovora na pitanje: 7158
# Status code: 200
# Id odgovora na pitanje: 7159
# Status code: 200
# Id pitanja: 7160
# Status code: 200
# Id odgovora na pitanje: 7161
# Status code: 200
# Id odgovora na pitanje: 7162
# Status code: 200
# Id odgovora na pitanje: 7163
# Status code: 200
# Id odgovora na pitanje: 7164
# Status code: 200
# Id odgovora na pitanje: 7165
# Status code: 200
# Id odgovora na pitanje: 7166
# Status code: 200
# Id odgovora na pitanje: 7167
# Status code: 200
# Id odgovora na pitanje: 7168
# Status code: 200
# Id odgovora na pitanje: 7169
# Status code: 200
# Id odgovora na pitanje: 7170
# Status code: 200
# Id pitanja: 7171
# Status code: 200
# Id odgovora na pitanje: 7172
# Status code: 200
# Id odgovora na pitanje: 7173
# Status code: 200
# Id odgovora na pitanje: 7174
# Status code: 200
# Id odgovora na pitanje: 7175
# Status code: 200
# Id odgovora na pitanje: 7176
# Status code: 200
# Id odgovora na pitanje: 7177
# Status code: 404
# Id izbrisanog pitanja: 7178
# Link stranice: https://cseducators.stackexchange.com/questions/7178/decryption-of-rsa-algorithm
# Naslov pitanja koje je obrisano: Decryption of rsa algorithm
# Obavijest o pitanju: This question was removed from Computer Science Educators Stack Exchange for reasons of moderation
# Pitanje je postojalo:  True
#
# Status code: 200
# Id odgovora na pitanje: 7179
# Status code: 200
# Id odgovora na pitanje: 7180
# Status code: 200
# Id odgovora na pitanje: 7181
# Status code: 200
# Id odgovora na pitanje: 7182
# Poslani id 7182 postoji već za pitanje sa id-em 1079
# Status code: 200
# Id odgovora na pitanje: 7183
# Poslani id 7183 postoji već za pitanje sa id-em 1079
# Status code: 200
# Id odgovora na pitanje: 7184
# Status code: 200
# Id odgovora na pitanje: 7185
# Poslani id 7185 postoji već za pitanje sa id-em 112
# Status code: 200
# Id pitanja: 7186
# Status code: 200
# Id odgovora na pitanje: 7187
# Status code: 200
# Id odgovora na pitanje: 7188
# Status code: 200
# Id odgovora na pitanje: 7189
# Status code: 200
# Id odgovora na pitanje: 7190
# Status code: 200
# Id odgovora na pitanje: 7191
# Status code: 200
# Id odgovora na pitanje: 7192
# Status code: 200
# Id odgovora na pitanje: 7193
# Status code: 200
# Id odgovora na pitanje: 7194
# Status code: 200
# Id odgovora na pitanje: 7195
# Status code: 200
# Id odgovora na pitanje: 7196
# Status code: 200
# Id odgovora na pitanje: 7197
# Status code: 200
# Id odgovora na pitanje: 7198
# Status code: 200
# Id pitanja: 7199
# Status code: 200
# Id odgovora na pitanje: 7200
# Status code: 200
# Id odgovora na pitanje: 7201
# Status code: 200
# Id odgovora na pitanje: 7202
# Status code: 200
# Id odgovora na pitanje: 7203
# Status code: 200
# Id odgovora na pitanje: 7204
# Status code: 200
# Id pitanja: 7205
# Status code: 200
# Id odgovora na pitanje: 7206
# Status code: 200
# Id odgovora na pitanje: 7207
# Poslani id 7207 postoji već za pitanje sa id-em 7199
# Status code: 200
# Id odgovora na pitanje: 7208
# Status code: 200
# Id odgovora na pitanje: 7209
# Status code: 200
# Id odgovora na pitanje: 7210
# Status code: 200
# Id odgovora na pitanje: 7211
# Status code: 200
# Id odgovora na pitanje: 7212
# Status code: 200
# Id odgovora na pitanje: 7213
# Status code: 200
# Id odgovora na pitanje: 7214
# Status code: 200
# Id odgovora na pitanje: 7215
# Status code: 200
# Id odgovora na pitanje: 7216
# Status code: 200
# Id odgovora na pitanje: 7217
# Status code: 200
# Id odgovora na pitanje: 7218
# Status code: 200
# Id odgovora na pitanje: 7219
# Status code: 200
# Id odgovora na pitanje: 7220
# Status code: 200
# Id pitanja: 7221
# Status code: 200
# Id odgovora na pitanje: 7222
# Status code: 200
# Id odgovora na pitanje: 7223
# Status code: 200
# Id odgovora na pitanje: 7224
# Status code: 200
# Id odgovora na pitanje: 7225
# Status code: 200
# Id pitanja: 7226
# Status code: 200
# Id odgovora na pitanje: 7227
# Status code: 200
# Id odgovora na pitanje: 7228
# Status code: 200
# Id odgovora na pitanje: 7229
# Status code: 200
# Id pitanja: 7230
# Status code: 200
# Id odgovora na pitanje: 7231
# Status code: 200
# Id odgovora na pitanje: 7232
# Status code: 200
# Id odgovora na pitanje: 7233
# Status code: 200
# Id pitanja: 7234
# Status code: 200
# Id odgovora na pitanje: 7235
# Status code: 200
# Id odgovora na pitanje: 7236
# Status code: 200
# Id odgovora na pitanje: 7237
# Status code: 200
# Id odgovora na pitanje: 7238
# Status code: 200
# Id pitanja: 7239
# Status code: 200
# Id odgovora na pitanje: 7240
# Status code: 200
# Id odgovora na pitanje: 7241
# Status code: 200
# Id odgovora na pitanje: 7242
# Status code: 200
# Id odgovora na pitanje: 7243
# Status code: 200
# Id odgovora na pitanje: 7244
# Status code: 200
# Id odgovora na pitanje: 7245
# Status code: 200
# Id odgovora na pitanje: 7246
# Status code: 200
# Id odgovora na pitanje: 7247
# Status code: 200
# Id pitanja: 7248

# %%
print("Duljina liste tagova:", len(list_wiki)) 
print("Duljina liste pitanja:", len(list_questions)) 
print("Duljina liste odgovora:", len(list_answers))
# Out:
# Duljina liste tagova: 204
# Duljina liste pitanja: 1332
# Duljina liste odgovora: 4192

# %%
#Spremamo liste u dataframe
data_wiki = pd.DataFrame(list_wiki, columns = ['Tag_ID','Title', 'Info'])
data_questions = pd.DataFrame(list_questions, columns=['Question_ID','Title','Content','Created at','User_ID','Is answered','Views count','Votes count','Bookmarks count','Answers count','Tags','Comments count', "Question existed"])
data_answers = pd.DataFrame(list_answers, columns = ['Answer_ID','Title', 'Content','User_ID','Date','Votes','Question_ID'])

# %%
print("Ukupan broj dohvaćenih pitanja:", data_questions.loc[data_questions['Question existed'] == False].shape[0])
# Out:
# Ukupan broj dohvaćenih pitanja: 1036

# %% [markdown]
# > Dohvaćeni podaci prikazani pomoću DataFramea

# %%
data_wiki.tail()
# Out:
#      Tag_ID  ...                                               Info
# 199    6345  ...  For questions about teaching programming (as o...
# 200    6479  ...  Concerning the two's complement representation...
# 201    6677  ...  The Classroom Environment pertains to things l...
# 202    6893  ...  For questions related to the design of a singl...
# 203    6917  ...  Questions related to mentoring students studyi...
#
# [5 rows x 3 columns]

# %%
data_wiki.shape
# Out:
# (204, 3)

# %%
data_questions.tail()
# Out:
#       Question_ID  ... Question existed
# 1327         7226  ...            False
# 1328         7230  ...            False
# 1329         7234  ...            False
# 1330         7239  ...            False
# 1331         7248  ...            False
#
# [5 rows x 13 columns]

# %%
data_questions.shape
# Out:
# (1332, 13)

# %%
data_answers.tail()
# Out:
#       Answer_ID  ... Question_ID
# 4187       7243  ...        7226
# 4188       7244  ...        7239
# 4189       7245  ...        7226
# 4190       7246  ...        7226
# 4191       7247  ...        3590
#
# [5 rows x 7 columns]

# %%
data_answers.shape
# Out:
# (4192, 7)

# %% [markdown]
# > Spremanje dohvaćenih podataka u csv datoteke

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Kreiramo putanju na drive-u i naziv dokumenta koji ce nam se stvorit te u njemu spremamo sve podatke koje imamo iz dataframe-a
path_w = '/content/drive/My Drive/data_wiki.csv'
with open(path_w,'w', encoding = 'utf-8-sig') as f:
  data_wiki.to_csv(f)

path_q = '/content/drive/My Drive/data_questions.csv'
with open(path_q,'w', encoding = 'utf-8-sig') as f:
  data_questions.to_csv(f)
  
path_a = '/content/drive/My Drive/data_answers.csv'
with open(path_a,'w', encoding = 'utf-8-sig') as f:
  data_answers.to_csv(f)
